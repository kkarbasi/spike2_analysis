# %%
from kaveh.behavioral.oculomotor.session import session
from kaveh.toolbox import find_file
from neo.io import Spike2IO
from matplotlib import pyplot as plt
import numpy as np
import quantities as pq
import csv
import os
try:
    import cPickle as pickle
except ModuleNotFoundError:
    import pickle

# %%
def bin_error_dirs(error_dirs):
    '''
    Bin error directions: Bins start from 157.5 and increaments counter-clockwise every 45 degrees => 8 bins, 0 to 7
    '''
    bins = np.arange(-180 + 22.5, 180, 45)
    bin_ind = np.digitize(error_dirs , bins, right=True)
    bin_ind[bin_ind == 8] = 0
    return bin_ind


def get_bin_cs_counts(cs_range, event_times, bin_ind, error_dir_bin_numbers, cs_times):
    '''
    get cs_counts for each bin
    '''
    cs_range = pq.quantity.Quantity(cs_range, 's')
    bin_cs_counts = []
    bin_cs_counts_backwards = []

    for ebn in error_dir_bin_numbers:
        bin_times = event_times[bin_ind == ebn]
        cs_count = 0
        cs_count_backwards = 0
        if bin_times.size != 0:
            for bt in bin_times:
                cs_count = cs_count + np.count_nonzero(np.where(np.logical_and(cs_times < bt+cs_range, cs_times > bt )))
                cs_count_backwards = cs_count_backwards + np.count_nonzero(np.where(np.logical_and(cs_times < bt, cs_times > bt - cs_range )))
            cs_count = cs_count*1.0/bin_times.size
            cs_count_backwards = cs_count_backwards*1.0/bin_times.size
            bin_cs_counts.append(cs_count)
            bin_cs_counts_backwards.append(cs_count_backwards)
        else:
            bin_cs_counts_backwards.append(0)
            bin_cs_counts.append(0)

        
    bin_cs_counts = np.array(bin_cs_counts)
    bin_cs_counts_backwards = np.array(bin_cs_counts_backwards)
#     bin_cs_counts = bin_cs_counts*1.0/np.sum(bin_cs_counts)
    return bin_cs_counts, bin_cs_counts_backwards

# %%
# These are Buckley files with the following event structure:
# Event 0
# Event 1
# Event 2
# Event 3 : Trial onset
# Event 4 : Primary target presentation in adaptation trials
# Event 5 : Corrective target presentation in adaptation trials
# Event 6 : Divide each trial into its target jumps
# Event 7 : 
buckley_files_correct_events = ['B082107_1340_List.smr', #yes
'B090407_1526_List.smr', # yes
# 'B091208_1545_List.smr', # No done
# 'B091608_1208_List.smr', # No done
'B091707_1414_List.smr', # No done
'B091908_1_1500_List.smr', # No done
'B091908_2_1550_List.smr', # No done
'B093008_1149_List.smr', # No done
'B100308_2_1403_List.smr', # No done
'W091008_1241_List.smr', # No done
'W091208_1337_List.smr', # No done: bimodal cs-on
'W120208_1_1418_List.smr', # No done
'W120508_1_1420_List.smr', # No done
'W120508_2_1628_List.smr'] # No

# f_name = '/mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B082107/B082107_1340_List.smr'
# f_name = '/mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B110807/B110807_1632_List.smr'

# %%
file_to_get_tuning_for = buckley_files_correct_events[0]

# %%
with open('../data/neurons_david_data_with_spike_train.csv', 'r') as csv_f:
    reader = csv.reader(csv_f)
    csv_content = np.array(list(reader))
file_names = np.array([fn[0] for fn in csv_content])

for i, fn in enumerate(file_names):
    print('{}: {}'.format(i, fn))
# Out:
# 0: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O22/O22_2Adapt_BW5L_FW5LCFRDone.smr
# 1: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O22/O22_2PreAdaptCFRDone.smr
# 2: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O13/O13_3_adapt40pct.smr
# 3: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O13/O13_3_adapt30pct.smr
# 4: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O13/O13_3_preadapt.smr
# 5: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O13/O13_3_adapt40pctB.smr
# 6: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O41/O41_1_FW5L_BW5R_A.smr
# 7: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O41/O41_1_pre.smr
# 8: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O29/O29_4Adapt_FW5L_BW5RCFR611sec.smr
# 9: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2006/Oscar/O29/O29_4PreAdaptCFRDone.smr
# 10: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K14/error_direction/K14_1_directionaltest.smr
# 11: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K14/error_magnitude/K14_1_errorsizetest.smr
# 12: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K33/error_direction/K33_1dirtest.smr
# 13: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K33/error_direction/K33_2dirtest.smr
# 14: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K33/error_magnitude/K33_1Verrortest.smr
# 15: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K33/error_magnitude/K33_2Herrortest.smr
# 16: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K45/error_direction/K45_1_ErrorDirectionTest.smr
# 17: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K45/error_magnitude/K45_1_ErrorSizetest315degDir.smr
# 18: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K21/error_direction/K21_2_directionaltest.smr
# 19: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K69/error_direction/K69_1_DirTuning.smr
# 20: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K69/error_magnitude/K69_1_ErrorSize45degDir.smr
# 21: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K40/error_direction/K40_1_Dirtuning.smr
# 22: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K40/error_magnitude/K40_1_ErrorSizeHorLINCOR.smr
# 23: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K16/error_direction/K16_2_directionaltest.smr
# 24: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S38/error_direction/S38_1_directionaltuning.smr
# 25: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S38/error_magnitude/S38_1_315degErrorTest.smr
# 26: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S36/error_direction/S36_1_directionaltuning.smr
# 27: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S36/error_magnitude/S36_1_135degErrorTest.smr
# 28: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S27/error_direction/S27_1_DirectionalTuning.smr
# 29: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S27/error_magnitude/S27_1_HorzErrorSizetest.smr
# 30: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S34/error_direction/S34_2_directionaltuning.smr
# 31: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S34/error_direction/S34_1_directionaltuning.smr
# 32: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S34/error_magnitude/S34_2_315degErrorTest.smr
# 33: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W111308/W111308_1604_Adapt.smr
# 34: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W091008/W091008_1241_List.smr
# 35: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W091008/W091008_1248_Adapt.smr
# 36: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120308_2/W120308_2_1714_List.smr
# 37: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120308_2/W120308_2_1622_Adapt.smr
# 38: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120108/W120108_1622_List.smr
# 39: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120108/W120108_1634_Adapt.smr
# 40: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120508_1/W120508_1_1429_Adapt.smr
# 41: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120508_1/W120508_1_1420_List.smr
# 42: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120508_2/W120508_2_1548_Adapt.smr
# 43: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120508_2/W120508_2_1628_List.smr
# 44: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W091208/W091208_1348_Adapt.smr
# 45: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W091208/W091208_1337_List.smr
# 46: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120208_1/W120208_1_1418_List.smr
# 47: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120208_1/W120208_1_1428_Adapt.smr
# 48: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B110807/B110807_1632_List.smr
# 49: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B101707/B101707_1333_List.smr
# 50: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B111507/B111507_1528_List.smr
# 51: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B082107/B082107_1340_List.smr
# 52: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B121407_1/B121407_1_1124_List.smr
# 53: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B121807/B121807_1135_List.smr
# 54: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B090407/B090407_1526_List.smr
# 55: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B082207/B082207_1505_List.smr
# 56: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_25deg/B091707/B091707_1414_List.smr
# 57: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F091106/F091106_0949_List.smr
# 58: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F091106/F091106_1002_Adapt.smr
# 59: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F090606/F090606_1325_Adapt.smr
# 60: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F090606/F090606_1313_List.smr
# 61: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F102506/F102506_1506_List.smr
# 62: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F102506/F102506_1518_Adapt.smr
# 63: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F112006/F112006_1446_List.smr
# 64: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F112006/F112006_1501_Adapt.smr
# 65: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F101106/F101106_1311_List.smr
# 66: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F101106/F101106_1324_Adapt.smr
# 67: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F102006/F102006_0933_Adapt.smr
# 68: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F102006/F102006_0916_List.smr
# 69: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F100906/F100906_1343_List.smr
# 70: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F100906/F100906_1358_Adapt.smr
# 71: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F110706/F110706_1413_List.smr
# 72: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F110706/F110706_1421_Adapt.smr
# 73: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F102706/F102706_1435_List.smr
# 74: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F102706/F102706_1449_Adapt.smr
# 75: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F101606/F101606_1323_Adapt.smr
# 76: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F101606/F101606_1308_List.smr
# 77: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F110206/F110206_1411_Adapt.smr
# 78: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F110206/F110206_1400_List.smr
# 79: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B101308/B101308_1342_List.smr
# 80: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B101308/B101308_1351_Adapt.smr
# 81: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B101308/B101308_1443_AdaptForward.smr
# 82: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091608/B091608_1218_Adapt.smr
# 83: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091608/B091608_1306_AdaptForward.smr
# 84: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091608/B091608_1429_AdaptCTRL.smr
# 85: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091608/B091608_1208_List.smr
# 86: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091908_2/B091908_2_1550_List.smr
# 87: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091908_2/B091908_21602_Adapt.smr
# 88: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091208/B091208_1545_List.smr
# 89: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091208/B091208_AdaptForward.smr
# 90: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091208/B091208_1554_Adapt.smr
# 91: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B100308_2/B100308_2_1403_List.smr
# 92: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B100308_2/B100308_2_1504_AdaptForward.smr
# 93: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B100308_2/B100308_2_1412_Adapt.smr
# 94: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B093008/B093008_1149_List.smr
# 95: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B093008/B093008_1200_Adapt.smr
# 96: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B093008/B093008_1242_AdaptForward.smr
# 97: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091908_1/B091908_1_1509_Adapt.smr
# 98: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091908_1/B091908_1_1500_List.smr

# %%
f_index =[10, 12, 13, 16, 18, 19, 21, 23, 26, 28, 30, 31, 34, 41, 43, 45, 46, 86, 91, 94, 98]
f_index = f_index + [57, 63, 65, 69, 71, 76, 78]
for i in f_index:
    print('{}: {}'.format(i, file_names[i]))
# Out:
# 10: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K14/error_direction/K14_1_directionaltest.smr
# 12: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K33/error_direction/K33_1dirtest.smr
# 13: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K33/error_direction/K33_2dirtest.smr
# 16: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K45/error_direction/K45_1_ErrorDirectionTest.smr
# 18: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K21/error_direction/K21_2_directionaltest.smr
# 19: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K69/error_direction/K69_1_DirTuning.smr
# 21: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K40/error_direction/K40_1_Dirtuning.smr
# 23: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K16/error_direction/K16_2_directionaltest.smr
# 26: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S36/error_direction/S36_1_directionaltuning.smr
# 28: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S27/error_direction/S27_1_DirectionalTuning.smr
# 30: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S34/error_direction/S34_2_directionaltuning.smr
# 31: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Step/S34/error_direction/S34_1_directionaltuning.smr
# 34: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W091008/W091008_1241_List.smr
# 41: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120508_1/W120508_1_1420_List.smr
# 43: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120508_2/W120508_2_1628_List.smr
# 45: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W091208/W091208_1337_List.smr
# 46: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Wyatt/W120208_1/W120208_1_1418_List.smr
# 86: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091908_2/B091908_2_1550_List.smr
# 91: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B100308_2/B100308_2_1403_List.smr
# 94: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B093008/B093008_1149_List.smr
# 98: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Buckley_12deg/B091908_1/B091908_1_1500_List.smr
# 57: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F091106/F091106_0949_List.smr
# 63: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F112006/F112006_1446_List.smr
# 65: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F101106/F101106_1311_List.smr
# 69: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F100906/F100906_1343_List.smr
# 71: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F110706/F110706_1413_List.smr
# 76: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F101606/F101606_1308_List.smr
# 78: /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F110206/F110206_1400_List.smr

# %%
import os
bin_cs_counts_for_file = {}
bin_cs_counts_iss_for_file = {}
bin_cs_counts_non_iss_for_file = {}

bin_cs_counts_backwards_for_file = {}
bin_cs_counts_iss_backwards_for_file = {}
bin_cs_counts_non_iss_backwards_for_file = {}

david_neurons_source = '/mnt/data/temp/kaveh/david_neurons/'
for bf in file_names[f_index]:
#     f_name = find_file(bf, '/mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt')
    f_name_csv = find_file(os.path.basename(bf)+'.pkl.GMM.CS.csv', david_neurons_source)
    
    f_name = find_file(os.path.basename(bf), '/mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data')
    f_name_session = find_file(os.path.basename(bf)+'.pkl.session.pkl', david_neurons_source)
    
    print(f_name)

    print(f_name_session)
    print(f_name_csv)
    neo_reader = Spike2IO(filename=f_name)
    neo_data = neo_reader.read()
    data_block = neo_data[0]
    seg = data_block.segments[0]
    events = seg.events
    
     # Load voltage
    t_signal = seg.analogsignals[-1].times
    signal_fs = seg.analogsignals[-1].sampling_rate
    


    # Load cs times from csGUI csv files

    with open(f_name_csv, 'r') as csv_f:
        reader = csv.reader(csv_f)
        csv_content = np.array(list(reader), dtype=np.int64)

    cs_indices = np.squeeze(csv_content[np.where(csv_content[:,1] == 1), 0])
    cs_times = t_signal[cs_indices]

    with open(f_name_session, 'rb') as input:
        try:
            mysess = pickle.load(input, encoding='latin1')
        except TypeError:
            mysess = pickle.load(input)
    # find inra-saccadic target jumps. For each saccade, check if that saccade is accompanied by a simultaneous target jump.
    # If so, it is an intra-saccadic target_jump. 
    # check 25 ms before and after the saccade onset and offset for the target jump onset and offset. if found, the target jump is intra-saccadic

    iss_range = pq.quantity.Quantity(0.025, 's')
    iss_targets = []
    iss_saccades = []
    saccades_with_no_iss_target = []
    for i, (son, soff) in enumerate(zip(mysess.saccade_onset_times, mysess.saccade_offset_times)):
        iss_targets.append(np.where(np.logical_or(np.logical_and(mysess.target_onset_times < son + iss_range, 
                                                                 mysess.target_onset_times > son - iss_range), 
                                                  np.logical_and(mysess.target_offset_times < soff + iss_range, 
                                                                 mysess.target_offset_times > soff - iss_range)))[0])
        if iss_targets[-1].size != 0:
            iss_saccades.append(i)
        if iss_targets[-1].size == 0:
            saccades_with_no_iss_target.append(i)

    iss_targets = np.squeeze(np.array([isst[0] for isst in iss_targets if isst.size != 0]))

    non_iss_target_jumps = np.setdiff1d(np.arange(mysess.target_onset_times.size), iss_targets)

    mysess._calc_error_vectors()

    error_dir_bin_ind = mysess.bin_error_dirs()
    error_mag_bin_ind = mysess.bin_error_mags()

    iss_saccades = np.array(iss_saccades)

    iss_saccades_bin_ind = bin_error_dirs(mysess.error_dir[iss_saccades])
    non_iss_saccades_bin_ind = bin_error_dirs(mysess.error_dir[saccades_with_no_iss_target])

    error_dir_bin_numbers = np.unique(error_dir_bin_ind)
    error_mag_bin_numbers = np.unique(error_mag_bin_ind)

    bin_cs_counts_for_file[bf], bin_cs_counts_backwards_for_file[fn] = get_bin_cs_counts(0.200, mysess.saccade_offset_times, error_dir_bin_ind, error_dir_bin_numbers, cs_times)
    bin_cs_counts_iss_for_file[bf], bin_cs_counts_iss_backwards_for_file[bf] = get_bin_cs_counts(0.200, mysess.saccade_offset_times[iss_saccades], iss_saccades_bin_ind, error_dir_bin_numbers, cs_times)
    bin_cs_counts_non_iss_for_file[bf],  bin_cs_counts_non_iss_backwards_for_file[bf] = get_bin_cs_counts(0.200, mysess.saccade_offset_times[saccades_with_no_iss_target], non_iss_saccades_bin_ind, error_dir_bin_numbers, cs_times)

    print(bin_cs_counts_for_file[bf])
    print(bin_cs_counts_iss_for_file[bf])
    print(bin_cs_counts_non_iss_for_file[bf])
# Out:
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K14/error_direction/K14_1_directionaltest.smr
# /mnt/data/temp/kaveh/david_neurons/K14/error_direction/K14_1_directionaltest.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/K14/error_direction/K14_1_directionaltest.smr.pkl.GMM.CS.csv
# [0.31130573 0.41647597 0.2915601  0.128125   0.08128079 0.11950791
#  0.14937759 0.23042506]
# [0.3699115  0.44407895 0.35684647 0.11888112 0.07142857 0.07901907
#  0.10789474 0.17111111]
# [0.2633864  0.35338346 0.18666667 0.20588235 0.21428571 0.19306931
#  0.19533528 0.24537815]
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K33/error_direction/K33_1dirtest.smr
# /mnt/data/temp/kaveh/david_neurons/K33/error_direction/K33_1dirtest.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/K33/error_direction/K33_1dirtest.smr.pkl.GMM.CS.csv
# [0.12093023 0.25365854 0.5        0.2826087  0.15178571 0.09183673
#  0.02352941 0.05882353]
# [0.11111111 0.27027027 0.57692308 0.33870968 0.12307692 0.109375
#  0.         0.0862069 ]
# [0.125      0.24427481 0.375      0.16666667 0.19148936 0.05882353
#  0.07692308 0.03846154]
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K33/error_direction/K33_2dirtest.smr
# /mnt/data/temp/kaveh/david_neurons/K33/error_direction/K33_2dirtest.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/K33/error_direction/K33_2dirtest.smr.pkl.GMM.CS.csv
# [0.3006135  0.14864865 0.06796117 0.02       0.         0.01538462
#  0.01538462 0.1369863 ]
# [0.43137255 0.34545455 0.08       0.01960784 0.         0.02
#  0.02       0.17391304]
# [0.24107143 0.08383234 0.05660377 0.02040816 0.         0.
#  0.         0.07407407]
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K45/error_direction/K45_1_ErrorDirectionTest.smr
# /mnt/data/temp/kaveh/david_neurons/K45/error_direction/K45_1_ErrorDirectionTest.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/K45/error_direction/K45_1_ErrorDirectionTest.smr.pkl.GMM.CS.csv
# [0.25806452 0.16022099 0.03908795 0.05       0.05063291 0.10526316
#  0.4556962  0.3125    ]
# [0.30769231 0.22       0.03370787 0.03539823 0.05714286 0.08510638
#  0.55357143 0.4893617 ]
# [0.21052632 0.13740458 0.0412844  0.08510638 0.         0.2
#  0.2173913  0.14285714]
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K21/error_direction/K21_2_directionaltest.smr
# /mnt/data/temp/kaveh/david_neurons/K21/error_direction/K21_2_directionaltest.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/K21/error_direction/K21_2_directionaltest.smr.pkl.GMM.CS.csv
# [0.11727617 0.0483871  0.03743316 0.06422018 0.03108808 0.11428571
#  0.29680365 0.23861852]
# [0.1547619  0.07692308 0.04580153 0.06451613 0.03246753 0.13291139
#  0.36363636 0.47741935]
# [0.1072     0.02777778 0.01785714 0.0625     0.02564103 0.08045977
#  0.17105263 0.16182573]
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K69/error_direction/K69_1_DirTuning.smr
# /mnt/data/temp/kaveh/david_neurons/K69/error_direction/K69_1_DirTuning.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/K69/error_direction/K69_1_DirTuning.smr.pkl.GMM.CS.csv
# [0.22516556 0.29       0.23076923 0.07894737 0.09174312 0.07246377
#  0.04347826 0.08490566]
# [0.22807018 0.46153846 0.25862069 0.05660377 0.         0.06666667
#  0.05263158 0.04444444]
# [0.22340426 0.22972973 0.15       0.13043478 0.19607843 0.08333333
#  0.         0.1147541 ]
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/Kimo/K40/error_direction/K40_1_Dirtuning.smr
# /mnt/data/temp/kaveh/david_neurons/K40/error_direction/K40_1_Dirtuning.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/K40/error_direction/K40_1_Dirtuning.smr.pkl.GMM.CS.csv
# [0.10594315 0.14210526 0.06923077 0.02890173 0.06271777 0.03960396
#  0.03319502 0.06940874]
# [0.17647059 0.15384615 0.07446809 0.02459016 0.08527132 0.05785124
#  0.02061856 0.05833333]
# [0.06772908 0.11666667 0.05555556 0.03921569 0.0443038  0.01234568
#  0.04166667 0.07434944]
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2008_Random/

# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F101606/F101606_1308_List.smr
# /mnt/data/temp/kaveh/david_neurons/F101606/F101606_1308_List.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/F101606/F101606_1308_List.smr.pkl.GMM.CS.csv
# [0.11111111 0.0952381  0.08333333 0.16713092 0.125      0.17708333
#  0.32857143 0.18461538]
# [0.09375    0.10344828 0.06382979 0.03125    0.02040816 0.09090909
#  0.34042553 0.20833333]
# [0.25       0.         0.15384615 0.19661017 0.16535433 0.29268293
#  0.30434783 0.11764706]
# /mnt/papers/Herzfeld_Nat_Neurosci_2018/raw_data/2010_Adapt/Felix/F110206/F110206_1400_List.smr
# /mnt/data/temp/kaveh/david_neurons/F110206/F110206_1400_List.smr.pkl.session.pkl
# /mnt/data/temp/kaveh/david_neurons/F110206/F110206_1400_List.smr.pkl.GMM.CS.csv
# [0.37804878 0.17391304 0.16393443 0.12328767 0.11290323 0.05454545
#  0.22727273 0.28888889]
# [0.4        0.08928571 0.07692308 0.02564103 0.10638298 0.04166667
#  0.35714286 0.36538462]
# [0.35135135 0.30555556 0.19847328 0.1588785  0.13333333 0.14285714
#  0.         0.18421053]

# %%
bins = np.arange(-180 + 22.5, 180, 45)
print(bins)
# Out:
# [-157.5 -112.5  -67.5  -22.5   22.5   67.5  112.5  157.5]

# %%
tunings_all = []
for val in bin_cs_counts_for_file.values():
    print(val)
    print(np.argmax(val))
    zero_idx = np.argmax(val)
    tunings_all.append(np.roll(val, 3-zero_idx , axis=0))
    
tunings_iss = []
for val in bin_cs_counts_iss_for_file.values():
    print(val)
    print(np.argmax(val))
    zero_idx = np.argmax(val)
    tunings_iss.append(np.roll(val, 3-zero_idx , axis=0))
    
tunings_non_iss = []
for val in bin_cs_counts_non_iss_for_file.values():
    print(val)
    print(np.argmax(val))
    zero_idx = np.argmax(val)
    tunings_non_iss.append(np.roll(val, 3-zero_idx , axis=0))
#     stim_tunings.append(np.roll(csv_content, 3-zero_idx , axis=1)[3,:])
# Out:
# [0.31130573 0.41647597 0.2915601  0.128125   0.08128079 0.11950791
#  0.14937759 0.23042506]
# 1
# [0.22516556 0.29       0.23076923 0.07894737 0.09174312 0.07246377
#  0.04347826 0.08490566]
# 1
# [0.04210526 0.12096774 0.20408163 0.27906977 0.16666667 0.27027027
#  0.12121212 0.03921569]
# 3
# [0.11727617 0.0483871  0.03743316 0.06422018 0.03108808 0.11428571
#  0.29680365 0.23861852]
# 6
# [0.1092437  0.12987013 0.125      0.15625    0.14634146 0.25
#  0.23076923 0.14201183]
# 5
# [0.3006135  0.14864865 0.06796117 0.02       0.         0.01538462
#  0.01538462 0.1369863 ]
# 0
# [0.29545455 0.16666667 0.06578947 0.10526316 0.04347826 0.13913043
#  0.2278481  0.43902439]
# 7
# [0.10594315 0.14210526 0.06923077 0.02890173 0.06271777 0.03960396
#  0.03319502 0.06940874]
# 1
# [0.33502538 0.17821782 0.12295082 0.06918239 0.13103448 0.15277778
#  0.38888889 0.32061069]
# 6
# [0.37735849 0.28333333 0.08       0.08695652 0.06097561 0.04347826
#  0.1884058  0.20454545]
# 0
# [0.18333333 0.16666667 0.1369863  0.13461538 0.11578947 0.14102564
#  0.28125    0.26923077]
# 6
# [0.26190476 0.18367347 0.17948718 0.22222222 0.38888889 0.19230769
#  0.19230769 0.13888889]
# 4
# [0.03030303 0.12195122 0.11111111 0.25581395 0.15384615 0.13636364
#  0.1        0.1       ]
# 3
# [0.30769231 0.22       0.03370787 0.03539823 0.05714286 0.08510638
#  0.55357143 0.4893617 ]
# 6
# [0.16666667 0.15625    0.08695652 0.25       0.2195122  0.17647059
#  0.16       0.18181818]
# 3
# [0.09375    0.10344828 0.06382979 0.03125    0.02040816 0.09090909
#  0.34042553 0.20833333]
# 6
# [0.04761905 0.16981132 0.24       0.46428571 0.37037037 0.1875
#  0.11111111 0.04166667]
# 3
# [0.05769231 0.04       0.08       0.03389831 0.06493506 0.2
#  0.26530612 0.1875    ]
# 6
# [0.11111111 0.27027027 0.57692308 0.33870968 0.12307692 0.109375
#  0.         0.0862069 ]
# 2
# [0.4        0.08928571 0.07692308 0.02564103 0.10638298 0.04166667
#  0.35714286 0.36538462]
# 0
# [0.25       0.18367347 0.21276596 0.46551724 0.43636364 0.34
#  0.24561404 0.32432432]
# 3
# [0.09375    0.125      0.04       0.35483871 0.39393939 0.60714286
#  0.26086957 0.20689655]
# 5
# [0.0877193  0.04545455 0.         0.03571429 0.18181818 0.37777778
#  0.32352941 0.1875    ]
# 5
# [0.13207547 0.21153846 0.13461538 0.10204082 0.26086957 0.10416667
#  0.12       0.16176471]
# 4
# [0.03157895 0.09195402 0.15306122 0.34042553 0.2173913  0.12048193
#  0.10958904 0.025     ]
# 3
# [0.27252252 0.26315789 0.17117117 0.12293144 0.14754098 0.13151365
#  0.14705882 0.21615202]
# 0
# [0.18181818 0.06382979 0.05813953 0.04395604 0.04597701 0.075
#  0.375      0.47435897]
# 7
# [0.17647059 0.09090909 0.12903226 0.3030303  0.60606061 0.61538462
#  0.4375     0.25      ]
# 5
# [0.2633864  0.35338346 0.18666667 0.20588235 0.21428571 0.19306931
#  0.19533528 0.24537815]
# 1
# [0.22340426 0.22972973 0.15       0.13043478 0.19607843 0.08333333
#  0.         0.1147541 ]
# 1
# [0.03448276 0.14942529 0.25       0.25       0.3        0.5
#  0.22222222 0.07692308]
# 5
# [0.1072     0.02777778 0.01785714 0.0625     0.02564103 0.08045977
#  0.17105263 0.16182573]
# 6
# [0.08571429 0.         0.23076923 0.33333333 0.16666667 0.22222222
#  0.21311475 0.10526316]
# 3
# [0.24107143 0.08383234 0.05660377 0.02040816 0.         0.
#  0.         0.07407407]
# 0
# [0.13333333 0.23809524 0.         0.1        0.05660377 0.17073171
#  0.19607843 0.23529412]
# 1
# [0.06772908 0.11666667 0.05555556 0.03921569 0.0443038  0.01234568
#  0.04166667 0.07434944]
# 1
# [0.30526316 0.19306931 0.12142857 0.14925373 0.14285714 0.18055556
#  0.28       0.28571429]
# 0
# [0.16666667 0.41666667 0.08       0.11290323 0.04347826 0.02777778
#  0.33333333 0.2       ]
# 1
# [0.14285714 0.22580645 0.2        0.18055556 0.23333333 0.29411765
#  0.22727273 0.15384615]
# 5
# [0.25581395 0.24242424 0.26666667 0.328125   0.46153846 0.33333333
#  0.11111111 0.28571429]
# 4
# [0.09090909 0.03846154 0.23976608 0.30985915 0.21212121 0.1
#  0.10526316 0.        ]
# 3
# [0.21052632 0.13740458 0.0412844  0.08510638 0.         0.2
#  0.2173913  0.14285714]
# 6
# [0.23076923 0.26923077 0.25       0.15789474 0.28571429 0.16666667
#  0.2987013  0.17948718]
# 6
# [0.25       0.         0.15384615 0.19661017 0.16535433 0.29268293
#  0.30434783 0.11764706]
# 6
# [0.14814815 0.17021277 0.18085106 0.29113924 0.08695652 0.26315789
#  0.22916667 0.1969697 ]
# 3
# [0.12121212 0.02325581 0.06741573 0.12105263 0.2037037  0.21818182
#  0.19512195 0.05882353]
# 5
# [0.125      0.24427481 0.375      0.16666667 0.19148936 0.05882353
#  0.07692308 0.03846154]
# 2
# [0.35135135 0.30555556 0.19847328 0.1588785  0.13333333 0.14285714
#  0.         0.18421053]
# 0
# [0.17241379 0.24242424 0.16666667 0.2        0.29411765 0.32673267
#  0.22794118 0.29090909]
# 5
# [0.13461538 0.11111111 0.4        0.5        1.         0.11111111
#  0.05882353 0.23376623]
# 4
# [0.04545455 0.01851852 0.03521127 0.14782609 0.1884058  0.17021277
#  0.13157895 0.15625   ]
# 4
# [0.         0.13333333 0.15584416 0.18292683 0.11702128 0.1884058
#  0.16       0.19642857]
# 7
# [0.08333333 0.14492754 0.16521739 0.25252525 0.21818182 0.13609467
#  0.08928571 0.06451613]
# 3
# [0.23464912 0.26449275 0.20531915 0.17133956 0.20915033 0.24252492
#  0.22277228 0.27166276]
# 7
# [0.12745098 0.14383562 0.15483871 0.08888889 0.08       0.07594937
#  0.09302326 0.19230769]
# 7
# [0.15909091 0.06666667 0.14285714 0.12903226 0.21621622 0.06666667
#  0.30434783 0.10869565]
# 6

# %%
backwards_tunings_all = []
for val in bin_cs_counts_backwards_for_file.values():
    print(val)
    print(np.argmax(val))
    zero_idx = np.argmax(val)
    backwards_tunings_all.append(np.roll(val, 3-zero_idx , axis=0))
    
backwards_tunings_iss = []
for val in bin_cs_counts_iss_backwards_for_file.values():
    print(val)
    print(np.argmax(val))
    zero_idx = np.argmax(val)
    backwards_tunings_iss.append(np.roll(val, 3-zero_idx , axis=0))
    
backwards_tunings_non_iss = []
for val in bin_cs_counts_non_iss_backwards_for_file.values():
    print(val)
    print(np.argmax(val))
    zero_idx = np.argmax(val)
    backwards_tunings_non_iss.append(np.roll(val, 3-zero_idx , axis=0))
# Out:
# [0.03658537 0.04347826 0.1420765  0.17123288 0.08064516 0.05454545
#  0.13636364 0.05555556]
# 3
# [0.15044248 0.12171053 0.12448133 0.12587413 0.11640212 0.22888283
#  0.2        0.14444444]
# 5
# [0.10526316 0.11538462 0.12068966 0.03773585 0.12068966 0.24444444
#  0.10526316 0.06666667]
# 5
# [0.21621622 0.13513514 0.         0.03225806 0.125      0.03703704
#  0.25       0.36      ]
# 7
# [0.11904762 0.18461538 0.34351145 0.2688172  0.18181818 0.15189873
#  0.07692308 0.08387097]
# 2
# [0.16326531 0.13636364 0.03703704 0.10344828 0.11428571 0.
#  0.2        0.17647059]
# 6
# [0.09803922 0.05454545 0.12       0.11764706 0.16363636 0.12
#  0.06       0.13043478]
# 4
# [0.20689655 0.15384615 0.36363636 0.44444444 0.28205128 0.42424242
#  0.21428571 0.16666667]
# 3
# [0.08088235 0.09230769 0.11702128 0.06557377 0.06976744 0.20661157
#  0.11340206 0.08333333]
# 5
# [0.03921569 0.07920792 0.1627907  0.27173913 0.20224719 0.22222222
#  0.14457831 0.08      ]
# 3
# [0.14285714 0.02777778 0.2        0.1        0.41666667 0.3030303
#  0.22222222 0.08333333]
# 4
# [0.07692308 0.06779661 0.10869565 0.265625   0.13846154 0.14754098
#  0.16666667 0.02564103]
# 3
# [0.19047619 0.16326531 0.23076923 0.16666667 0.13888889 0.15384615
#  0.26923077 0.13888889]
# 6
# [0.03030303 0.09756098 0.11111111 0.11627907 0.11538462 0.04545455
#  0.23333333 0.13333333]
# 6
# [0.16483516 0.19       0.35955056 0.38938053 0.38571429 0.19148936
#  0.125      0.08510638]
# 3
# [0.43333333 0.375      0.13043478 0.08333333 0.17073171 0.11764706
#  0.2        0.27272727]
# 0
# [0.0625     0.10344828 0.27659574 0.21875    0.16326531 0.12727273
#  0.04255319 0.10416667]
# 2
# [0.11904762 0.1509434  0.14       0.08928571 0.22222222 0.22916667
#  0.2        0.18055556]
# 5
# [0.23076923 0.18       0.14       0.08474576 0.1038961  0.11666667
#  0.14285714 0.09375   ]
# 0
# [0.0952381  0.18918919 0.15384615 0.06451613 0.07692308 0.171875
#  0.28813559 0.27586207]
# 6
# [0.02222222 0.01785714 0.03846154 0.17948718 0.08510638 0.0625
#  0.17857143 0.01923077]
# 3
# [0.27083333 0.28571429 0.12765957 0.15517241 0.12727273 0.1
#  0.33333333 0.40540541]
# 7
# [0.40625    0.325      0.28       0.12903226 0.         0.10714286
#  0.2173913  0.27586207]
# 0
# [0.1754386  0.22727273 0.15384615 0.08928571 0.14545455 0.06666667
#  0.02941176 0.0625    ]
# 1
# [0.26415094 0.07692308 0.13461538 0.10204082 0.04347826 0.16666667
#  0.14       0.26470588]
# 7
# [0.22105263 0.11494253 0.13265306 0.13829787 0.10869565 0.13253012
#  0.16438356 0.2875    ]
# 7
# [0.21171171 0.21842105 0.16216216 0.21513002 0.23419204 0.21588089
#  0.15240642 0.20427553]
# 4
# [0.08080808 0.07446809 0.29069767 0.36263736 0.1954023  0.2
#  0.05       0.06410256]
# 3
# [0.14705882 0.33333333 0.16129032 0.03030303 0.03030303 0.07692308
#  0.09375    0.10714286]
# 1
# [0.25470333 0.2481203  0.27333333 0.26470588 0.17857143 0.12871287
#  0.1516035  0.23697479]
# 2
# [0.18085106 0.25       0.15       0.08695652 0.05882353 0.08333333
#  0.         0.1147541 ]
# 1
# [0.12068966 0.10344828 0.20833333 0.08333333 0.2        0.2
#  0.11111111 0.11538462]
# 2
# [0.2032     0.15       0.17857143 0.375      0.30769231 0.16091954
#  0.17105263 0.17219917]
# 3
# [0.18571429 0.15151515 0.23076923 0.33333333 0.         0.11111111
#  0.26229508 0.16447368]
# 3
# [0.16964286 0.14371257 0.18867925 0.26530612 0.21428571 0.
#  0.         0.        ]
# 3
# [0.26666667 0.47619048 0.3255814  0.25       0.20754717 0.14634146
#  0.19607843 0.23529412]
# 1
# [0.08366534 0.21666667 0.16666667 0.07843137 0.08227848 0.14814815
#  0.06944444 0.05204461]
# 1
# [0.27368421 0.22277228 0.15357143 0.17910448 0.14285714 0.11111111
#  0.2        0.33928571]
# 7
# [0.33333333 0.125      0.16       0.19354839 0.10869565 0.19444444
#  0.21212121 0.35      ]
# 7
# [0.04761905 0.19354839 0.17       0.14583333 0.13333333 0.11764706
#  0.         0.07692308]
# 1
# [0.1627907  0.29090909 0.2047619  0.296875   0.07692308 0.16666667
#  0.11111111 0.42857143]
# 7
# [0.         0.23076923 0.14619883 0.26760563 0.18181818 0.15
#  0.36842105 0.7       ]
# 7
# [0.44210526 0.22519084 0.10550459 0.06382979 0.22222222 0.1
#  0.2173913  0.42857143]
# 0
# [0.19230769 0.30769231 0.08333333 0.26315789 0.19047619 0.06666667
#  0.23376623 0.24358974]
# 1
# [0.         0.2        0.23076923 0.07118644 0.12598425 0.26829268
#  0.34782609 0.23529412]
# 6
# [0.18518519 0.12765957 0.13297872 0.33544304 0.34782609 0.15789474
#  0.16666667 0.1969697 ]
# 4
# [0.15151515 0.1627907  0.12359551 0.09473684 0.19444444 0.09090909
#  0.09756098 0.17647059]
# 4
# [0.18421053 0.32061069 0.34375    0.13333333 0.17021277 0.14705882
#  0.11538462 0.03846154]
# 2
# [0.05405405 0.08333333 0.18320611 0.1682243  0.06666667 0.
#  0.0625     0.10526316]
# 2
# [0.17241379 0.3030303  0.26190476 0.28888889 0.2745098  0.33663366
#  0.30147059 0.32727273]
# 5
# [0.25       0.22222222 0.4        0.5        1.         0.44444444
#  0.23529412 0.24675325]
# 4
# [0.13636364 0.11111111 0.11267606 0.12173913 0.11594203 0.27659574
#  0.18421053 0.21875   ]
# 5
# [0.4        0.66666667 0.11688312 0.15243902 0.14893617 0.08695652
#  0.1        0.19642857]
# 1
# [0.14583333 0.14492754 0.10434783 0.05050505 0.08181818 0.10059172
#  0.10714286 0.09677419]
# 0
# [0.18201754 0.2192029  0.15638298 0.1588785  0.12745098 0.16943522
#  0.16336634 0.19672131]
# 1
# [0.2254902  0.14383562 0.09032258 0.15555556 0.12       0.05063291
#  0.13953488 0.31538462]
# 7
# [0.20454545 0.17777778 0.35714286 0.25806452 0.37837838 0.4
#  0.2173913  0.2826087 ]
# 5

# %%
# tunings_all = np.array(tunings_all)
# print(tunings_all.shape)

backwards_tunings_iss = np.array(backwards_tunings_iss)
print(backwards_tunings_iss.shape)

backwards_tunings_non_iss = np.array(backwards_tunings_non_iss)
print(backwards_tunings_non_iss.shape)
# Out:
# (28, 8)
# (28, 8)

# %%
tunings_iss = np.array(tunings_iss)
print(tunings_iss.shape)

tunings_non_iss = np.array(tunings_non_iss)
print(tunings_non_iss.shape)
# Out:
# (28, 8)
# (28, 8)

# %%
mean_non_iss = np.mean(tunings_non_iss, axis = 0)
sd_non_iss = np.std(tunings_non_iss, axis = 0)/np.sqrt(tunings_non_iss.shape[0]-1)

mean_iss = np.mean(tunings_iss, axis = 0)
sd_iss = np.std(tunings_iss, axis = 0)/np.sqrt(tunings_iss.shape[0]-1)

# %%
backwards_mean_non_iss = np.mean(backwards_tunings_non_iss, axis = 0)
backwards_sd_non_iss = np.std(backwards_tunings_non_iss, axis = 0)/np.sqrt(backwards_tunings_non_iss.shape[0]-1)

backwards_mean_iss = np.mean(backwards_tunings_iss, axis = 0)
backwards_sd_iss = np.std(backwards_tunings_iss, axis = 0)/np.sqrt(backwards_tunings_iss.shape[0]-1)

# %%
# %matplotlib notebook

# %%
x = [-135, -90, -45, 0, 45, 90, 135, 180]
plt.figure(figsize=(8,7))
l = plt.plot(x, backwards_mean_non_iss, 'r')
plt.fill_between(x, backwards_mean_non_iss - backwards_sd_non_iss, backwards_mean_non_iss + backwards_sd_non_iss, color=l[0].get_color(), alpha=0.25)

l = plt.plot(x, backwards_mean_iss)
plt.fill_between(x, backwards_mean_iss - backwards_sd_iss, backwards_mean_iss + backwards_sd_iss, color=l[0].get_color(), alpha=0.25)
plt.xticks(x,x)

plt.xlabel('Degrees from CS-ON')
plt.ylabel('CS Probability')
plt.legend(['wrt sac. offset w/o intra-sac. target jump','wrt saccade offset w/ intra-sac. target jump'])

# %%
x = [-135, -90, -45, 0, 45, 90, 135, 180]
plt.figure(figsize=(8,7))
l = plt.plot(x, mean_non_iss, 'r')
plt.fill_between(x, mean_non_iss - sd_non_iss, mean_non_iss + sd_non_iss, color=l[0].get_color(), alpha=0.25)

l = plt.plot(x, mean_iss)
plt.fill_between(x, mean_iss - sd_iss, mean_iss + sd_iss, color=l[0].get_color(), alpha=0.25)
plt.xticks(x,x)

plt.xlabel('Degrees from CS-ON')
plt.ylabel('CS Probability')
plt.legend(['wrt sac. offset w/o intra-sac. target jump','wrt saccade offset w/ intra-sac. target jump'])

# %%
x = [-135, -90, -45, 0, 45, 90, 135, 180]
plt.figure(figsize=(8,7))
l = plt.plot(x, mean_iss, 'r')
plt.fill_between(x, mean_iss - sd_iss, mean_iss + sd_iss, color=l[0].get_color(), alpha=0.25)

l = plt.plot(x, backwards_mean_iss)
plt.fill_between(x, backwards_mean_iss - backwards_sd_iss, backwards_mean_iss + backwards_sd_iss, color=l[0].get_color(), alpha=0.25)
plt.xticks(x,x)


plt.xlabel('Degrees from CS-ON')
plt.ylabel('CS Probability')
plt.legend(['forwards','backwards'])

# %%
theta = np.array([-135, -90, -45, 0, 45, 90, 135, 180])*np.pi/180
plt.figure(figsize=(10,10))
plt.polar(np.hstack((theta, theta[0])), np.hstack((mean_iss , mean_iss[0])), alpha = 0.02,color = 'b' )
plt.fill_between( np.hstack((theta, theta[0])),0, np.hstack((mean_iss , mean_iss[0])), alpha = 0.5, color = 'b')

plt.polar(np.hstack((theta, theta[0])), np.hstack((backwards_mean_iss , backwards_mean_iss[0])), alpha = 0.02,color = 'r' )
plt.fill_between(np.hstack((theta, theta[0])),0, np.hstack((backwards_mean_iss , backwards_mean_iss[0])), alpha = 0.5, color = 'r')
plt.title('blue: soff forwards; red: soff backwards')
# Out:
# <img src="data:image/png;base64,..." width="1111.1111405455044">
# Text(0.5,1.05,u'blue: soff forwards; red: soff backwards')

# %%
plt.savefig('../data/plots/Saliency_stuff/cs_tuning_with_respect_to_primary_sac_offset_forwards_and_backwards_polar_200ms.png')
plt.savefig('../data/plots/Saliency_stuff/cs_tuning_with_respect_to_primary_sac_offset_forwards_and_backwards_polar_200ms.svg')

# %%
theta = np.array([-135, -90, -45, 0, 45, 90, 135, 180])*np.pi/180
plt.figure(figsize=(10,10))
plt.polar(np.hstack((theta, theta[0])), np.hstack((mean_iss , mean_iss[0])), alpha = 0.02,color = 'b' )
plt.fill_between( np.hstack((theta, theta[0])),0, np.hstack((mean_iss , mean_iss[0])), alpha = 0.5, color = 'b')

plt.polar(np.hstack((theta, theta[0])), np.hstack((mean_non_iss , mean_non_iss[0])), alpha = 0.02,color = 'r' )
plt.fill_between(np.hstack((theta, theta[0])),0, np.hstack((mean_non_iss , mean_non_iss[0])), alpha = 0.5, color = 'r')
plt.title('blue: aligend to primary saccade offset; red: aligned to all other saccades')
# Out:
# <img src="data:image/png;base64,..." width="1111.1111405455044">
# Text(0.5,1.05,u'blue: aligend to primary saccade offset; red: aligned to all other saccades')

# %%
plt.savefig('../data/plots/Saliency_stuff/cs_tuning_with_respect_to_primary_sac_offset_and_all_other_saccades_200ms.png')
plt.savefig('../data/plots/Saliency_stuff/cs_tuning_with_respect_to_primary_sac_offset_and_all_other_saccades_200ms.svg')

# %%
x = [-135, -90, -45, 0, 45, 90, 135, 180]
plt.figure(figsize=(8,7))


l = plt.plot(x, mean_iss)
plt.fill_between(x, mean_iss - sd_iss, mean_iss + sd_iss, color=l[0].get_color(), alpha=0.25)

l = plt.plot(x, mean_non_iss, 'r')
plt.fill_between(x, mean_non_iss - sd_non_iss, mean_non_iss + sd_non_iss, color=l[0].get_color(), alpha=0.25)
plt.xticks(x,x)

plt.xlabel('Degrees from CS-ON')
plt.ylabel('CS Probability')
plt.legend(['Following the primary saccade offset', 'Following all other saccades'])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
plt.title('n = 30')
# Out:
# Text(0.5,1,u'n = 30')

# %%
plt.savefig('../data/plots/Saliency_stuff/tuning_with_respect_to_sac_endpoint_GMM_cs_30_neurons_for_sfn_correct_alignment.png')
plt.savefig('../data/plots/Saliency_stuff/tuning_with_respect_to_sac_endpoint_GMM_cs_30_neurons_for_sfn_correct_alignment.svg')

# %%
plt.figure()
plt.plot(np.mean(tunings_non_iss, axis = 0))

# %%
print(val)
print(np.roll(val, 2, axis=0))
# Out:
# [0.11940299 0.05263158 0.1        0.15151515 0.22580645 0.41666667
#  0.25       0.12264151]
# [0.25       0.12264151 0.11940299 0.05263158 0.1        0.15151515
#  0.22580645 0.41666667]

# %%
count = 0
_sum = 0
for key in bin_cs_counts_for_file:
    count += 1
    _sum += bin_cs_counts_for_file[key]

# %%
# Out:
# array([0.11584062, 0.0948156 , 0.11943885, 0.15345987, 0.1575367 ,
#        0.18213765, 0.14851073, 0.10212838])
